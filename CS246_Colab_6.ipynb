# %% [markdown]
# # CS246 - Colab 6
# ## node2vec

# %% [markdown]
# ### Setup

# %% [markdown]
# First of all, we install the [graph2vec library](https://github.com/VHRanger/graph2vec) which offers a fast implementation of the node2vec method.
#
# If you are curious to learn how to implement fast random walks on graphs, I recommend you to [read the blog post](https://www.singlelunch.com/2019/08/01/700x-faster-node2vec-models-fastest-random-walks-on-a-graph/) which explains some of the design choices behind this library.

# %%
# !python -m pip install 'csrgraph @ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7'
# !python -m pip install 'nodevectors @ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2'
# Out:
# Collecting csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7
#   Cloning https://github.com/VHRanger/CSRGraph (to revision f052c1cf128ab21d21a4710337dc7c1cd5658df7) to /tmp/pip-install-wuzo5pnn/csrgraph_a39001e04d9f49e1939b5033d3d237ae
#   Running command git clone --filter=blob:none --quiet https://github.com/VHRanger/CSRGraph /tmp/pip-install-wuzo5pnn/csrgraph_a39001e04d9f49e1939b5033d3d237ae
#   Running command git rev-parse -q --verify 'sha^f052c1cf128ab21d21a4710337dc7c1cd5658df7'
#   Running command git fetch -q https://github.com/VHRanger/CSRGraph f052c1cf128ab21d21a4710337dc7c1cd5658df7
#   Resolved https://github.com/VHRanger/CSRGraph to commit f052c1cf128ab21d21a4710337dc7c1cd5658df7
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (3.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (4.65.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->csrgraph@ git+https://github.com/VHRanger/CSRGraph@f052c1cf128ab21d21a4710337dc7c1cd5658df7) (1.16.0)
# Building wheels for collected packages: csrgraph
#   Building wheel for csrgraph (setup.py) ... done
#   Created wheel for csrgraph: filename=csrgraph-0.1.29-py3-none-any.whl size=19399 sha256=be372bf9ec1db34c87c91a64a81211432167a7650102b774030aab2c490b4000
#   Stored in directory: /root/.cache/pip/wheels/9b/b2/53/46e2e64492e0bdfaab6d5eb9d1c147dcaa8f883bca0613fba7
# Successfully built csrgraph
# Installing collected packages: csrgraph
# Successfully installed csrgraph-0.1.29
# Collecting nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2
#   Cloning https://github.com/aman0456/nodevectors (to revision 67e9af0506236be9aae6d460e96d4dec6329bcd2) to /tmp/pip-install-an2dy8ah/nodevectors_189f2b28b9084235954e0402fb7fe41b
#   Running command git clone --filter=blob:none --quiet https://github.com/aman0456/nodevectors /tmp/pip-install-an2dy8ah/nodevectors_189f2b28b9084235954e0402fb7fe41b
#   Running command git rev-parse -q --verify 'sha^67e9af0506236be9aae6d460e96d4dec6329bcd2'
#   Running command git fetch -q https://github.com/aman0456/nodevectors 67e9af0506236be9aae6d460e96d4dec6329bcd2
#   Running command git checkout -q 67e9af0506236be9aae6d460e96d4dec6329bcd2
#   Resolved https://github.com/aman0456/nodevectors to commit 67e9af0506236be9aae6d460e96d4dec6329bcd2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: csrgraph in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (0.1.29)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (4.3.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (3.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (1.22.4)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (2022.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from csrgraph->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (4.65.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (6.3.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (67.7.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->nodevectors@ git+https://github.com/aman0456/nodevectors@67e9af0506236be9aae6d460e96d4dec6329bcd2) (1.16.0)
# Building wheels for collected packages: nodevectors
#   Building wheel for nodevectors (setup.py) ... done
#   Created wheel for nodevectors: filename=nodevectors-0.1.23-py3-none-any.whl size=18810 sha256=1355a1903f0c57be035feedf5dfd089f0768b3fc65bf79339fa4c96311a0c579
#   Stored in directory: /root/.cache/pip/wheels/d5/3e/71/c6c1b9a3faa90a8672db8c915358b27f2d69269f8b361a4a97
# Successfully built nodevectors
# Installing collected packages: nodevectors
# Successfully installed nodevectors-0.1.23

# %% [markdown]
# We now import the library, and create a small wrapper class which will expose only the few hyperparameters we will need to tune in this Colab

# %%
from nodevectors import Node2Vec
import networkx as nx

class Node2VecNew(Node2Vec):
  """
  Parameters
  ----------
  p : float
      p parameter of node2vec
  q : float
      q parameter of node2vec
  d : int
      dimensionality of the embedding vectors
  """
  def __init__(self, p=1, q=1, d=32):
    super().__init__(
                 n_components=d,
                     walklen=10,
                     epochs=50,
                     return_weight=1.0/p,
                     neighbor_weight=1.0/q,
                     threads=0,
                     w2vparams={'window': 4,
                                'negative': 5,
                                'iter': 10,
                                'ns_exponent': 0.5,
                                'batch_words': 128})

# %% [markdown]
# Lastly, let's import some of the common libraries needed for our task.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
# %matplotlib inline

# %% [markdown]
# ### Example
#
# In the example below, we will try to reproduce the plot in slide 8 of [CS246 - Lecture 12](http://web.stanford.edu/class/cs246/slides/12-graphs2.pdf).

# %%
# Load the Zachary's Karate Club as a NetworkX Graph object
KCG = nx.karate_club_graph()

# Fit embedding model to the Karate Club graph
n2v = Node2VecNew(1, 1, 2)
n2v.fit(KCG)
# Out:
# Making walks... Done, T=3.76
# Mapping Walk Names... Done, T=0.04
# Training W2V... WARNING: gensim word2vec version is unoptimizedTry version 3.6 if on windows, versions 3.7 and 3.8 have had issues
# Done, T=0.31

# %%
embeddings = []
for node in KCG.nodes:
  embedding = list(n2v.predict(node))
  club = KCG.nodes[node]['club']
  embeddings.append(embedding + [club])

# Construct a pandas dataframe with the 2D embeddings from node2vec,
# plus the club name that each node belongs to after the split
df = pd.DataFrame(embeddings, columns=['x', 'y', 'club'])

# %%
# Nodes who stayed with the Mr. Hi will be plotted in red, while nodes
# who moved with the Officer will be plotted in blue
colors = ['red' if x == 'Mr. Hi' else 'blue' for x in df.club]
df.plot.scatter(x='x', y='y', s=50, c=colors)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# If our example trained correctly, you should notice a clear separation between the blue and red nodes.  Solely from the graph structure, node2vec could predict how the Zachary's Karate Club split!
#
# Tune the hyperparameters ```p``` and ```q```, and notice how they affect the resulting embeddings.

# %% [markdown]
# ### Your Task

# %% [markdown]
# Now we will study the behavior of node2vec on [barbell graphs](https://en.wikipedia.org/wiki/Barbell_graph).
#
# Below you can see a toy example of a barbell graph generated with NetworkX.

# %%
toy_barbell = nx.barbell_graph(7, 0)
nx.draw_kamada_kawai(toy_barbell)

# %% [markdown]
# Generate a larger barbell graph, where each complete graph has exactly 1000 nodes.
#
# Then, learn node2vec embeddings on this graph, setting ```p = 1, q = 1``` and ```d = 10```.

# %%
''' 5-7 lines of code in total expected but can differ based on your style.
For sub-parts of the question (if any), creating different cells of code would be recommended.'''
# YOUR CODE HERE
barbell_1k = nx.barbell_graph(1000, 0)

# %%
n2v_barbell_1k = Node2VecNew(p= 1, q= 1, d= 10)
n2v_barbell_1k.fit(barbell_1k)
# Out:
# Making walks... Done, T=0.74
# Mapping Walk Names... Done, T=1.40
# Training W2V... WARNING: gensim word2vec version is unoptimizedTry version 3.6 if on windows, versions 3.7 and 3.8 have had issues
# Done, T=23.29

# %% [markdown]
# Write a function that takes as input a node id ```n``` in the graph (e.g., ```5```) and returns a list containining the cosine similarity between the node2vec vector of the input node ```n``` and all the nodes in the given barbell graph (including the similarity with ```n``` itself).

# %%
''' 24-30 lines of code in total expected but can differ based on your style.
For sub-parts of the question (if any), creating different cells of code would be recommended.'''

# YOUR CODE HERE
import numpy as np

def node_embeddings(barbell_1k, n2v_barbell_1k):
  embeddings = []
  for node in barbell_1k.nodes:
    embedding = list(n2v_barbell_1k.predict(node))
    embeddings.append(embedding)
  return embeddings

def cosine_similarity_one2all(input_node, embeddings):
  result = []
  for emb in embeddings:
    cosine_similarity = np.dot(embeddings[input_node], emb) / (np.linalg.norm(embeddings[input_node]) * np.linalg.norm(emb))
    result.append(cosine_similarity)
  return result

embeddings = node_embeddings(barbell_1k, n2v_barbell_1k)
cosine_similarity_one2all(5, embeddings)[:6]
# Out:
# [0.918881, 0.9274655, 0.9452764, 0.94311154, 0.88398254, 1.0000001]

# %% [markdown]
# Generate another barbell graph, this time adding a path of length 51 between
#
# ---
#
# the two complete graphs. To find out how, refer to the NetworkX documentation: [https://networkx.github.io/documentation/stable/reference/
#
# ---
#
# generated/networkx.generators.classic.barbell_graph.html#networkx.generators.classic.barbell_graph](https://networkx.github.io/documentation/stable/reference/generated/networkx.generators.classic.barbell_graph.html#networkx.generators.classic.barbell_graph)
#
# Learn the node2vec embeddings for the nodes of this new graph, using the same hyperparameters as before.

# %%
''' 10-12 lines of code in total expected but can differ based on your style.
For sub-parts of the question (if any), creating different cells of code would be recommended.'''
# YOUR CODE HERE
barbell_51 = nx.barbell_graph(1000, 50)
n2v_barbell_51 = Node2VecNew(p= 1, q= 1, d= 10)
n2v_barbell_51.fit(barbell_51)
embeddings = node_embeddings(barbell_51, n2v_barbell_51)
cosine_similarity_one2all(5, embeddings)[:6]
# Out:
# Making walks... Done, T=0.54
# Mapping Walk Names... Done, T=0.69
# Training W2V... WARNING: gensim word2vec version is unoptimizedTry version 3.6 if on windows, versions 3.7 and 3.8 have had issues
# Done, T=25.29
# [0.93137836, 0.92935336, 0.93223596, 0.8727308, 0.8832391, 0.99999994]

# %% [markdown]
# Once you have working code for each cell above, **head over to Gradescope, read carefully the questions, and submit your solution for this Colab**!
